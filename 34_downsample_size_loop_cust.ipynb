# %%
# Modify the file 00_setup.py to define input/output file paths on your system
# The information in 00_setup.py will be used across notebooks
from importlib.machinery import SourceFileLoader
setup = SourceFileLoader("setup", "./00_setup.py").load_module()

# %% [markdown]
# ## Loop downsample size - data generator randomization, NAICS base
# Randomize training during fit (shuffled), loop downsampling training data.  Loop the downsample fraction.  (Fixed random injection at 10%

# %% [markdown]
# Base NAICS only, and data with no missing values

# %% [markdown]
# *This script takes about 2 hours on my MacBook Air*

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from pathlib import Path
import importlib, pickle
from sklearn import model_selection
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import os
import re

import keras
from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, feature_extraction, model_selection
from IPython.display import display, HTML
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.ticker as ticker

# %%
from keras.callbacks import EarlyStopping

# %%
from sba_nn.sba_nn import sbnn_metrics, sbnn_model, sbnn_plot
from sba_nn.sba_nn.sbnn_model import CatInjectGenerator

# %%
sbnn_plot.plot_defaults()

# %% [markdown]
# ## Input Data

# %%
sba_loans = pd.read_parquet(Path(setup.temp_path).joinpath('01_DATA_transformed_nomiss.parquet'))

# %%
with open(Path(setup.temp_path).joinpath('01_DATA_features.pkl'), 'rb') as fin:
    imputer_features = pickle.load(fin)

# %%
with open(Path(setup.temp_path).joinpath('01_DATA_naics_max_encodings.pkl'), 'rb') as fin:
    naics_max_levels= pickle.load(fin)

# %% [markdown]
# ##### Features

# %%
# Numeric features
features_numeric = [f for f in imputer_features if 'NAICS' not in f]
features_numeric_len = len(features_numeric)
print(features_numeric)
# Out:
# ['NoEmp', 'CreateJob', 'LowDoc', 'DisbursementGross', 'new_business', 'urban_flag', 'franchise_flag', 'missingindicator_LowDoc', 'missingindicator_new_business', 'missingindicator_urban_flag']

# %%
###### NAICS feature
features_naics = ['NAICS']
features_naics_max_levels  = [naics_max_levels[n] for n in features_naics]
features_naics_emb_dim = [setup.nn_naics_embed_size_dict[n] for n in features_naics]

# %%
print(features_naics_max_levels)
print(features_naics_emb_dim)
# Out:
# [1170]
# [8]

# %% [markdown]
# ##### Datasets for train, validation

# %%
X = sba_loans[['dset', 'LoanNr_ChkDgt'] + features_numeric + features_naics].set_index('LoanNr_ChkDgt').sort_index()

# %%
X_train = X[X['dset'] == 'train'].drop(columns='dset')
y_train = sba_loans[sba_loans['dset'] == 'train'].set_index('LoanNr_ChkDgt').sort_index()['target']
print(f'training X: {X_train.shape}, y:{y_train.shape}')
# Out:
# training X: (446848, 11), y:(446848,)

# %%
X_val = X[X['dset'] == 'val'].drop(columns='dset')
y_val = sba_loans[sba_loans['dset'] == 'val'].set_index('LoanNr_ChkDgt').sort_index()['target']
print(f'val X: {X_val.shape}, y:{y_val.shape}')
# Out:
# val X: (95604, 11), y:(95604,)

# %%
base_thresh = y_train.mean()
print(base_thresh)
# Out:
# 0.20230592953308507

# %% [markdown]
# ## Create, fit model

# %% [markdown]
# ## Loop for different fits

# %%
def gen_fit_loop(rate=0.1, injection_rate = 0.1):
    this_model = sbnn_model.create_emb_model(features_numeric_len,
                                         features_naics_max_levels,
                                         features_naics_emb_dim,
                                         naics_embedding_names = features_naics,
                                         hidden_size = setup.nn_layer_sizes,
                                         activation='tanh',
                                         lr=setup.nn_learning_rate,
                                         opt_func = setup.nn_optimizer,
                                         dropout = setup.nn_dropout)
    
    # Downsample
    train_samp, _ = train_test_split(X_train.index,
                                train_size=rate,
                                random_state=343)
    X_train_ds = X_train.loc[train_samp, :]
    y_train_ds = y_train.loc[train_samp]
    
    
    generator = CatInjectGenerator(X_train_ds, y_train_ds,
                               categorical_columns=features_naics,
                               batch_size = setup.nn_batch_size,
                               injection_rate = injection_rate,
                               injection_value = 1)
    callback = keras.callbacks.EarlyStopping(patience=3)
    
    this_history = this_model.fit(generator,
                              batch_size=setup.nn_batch_size,
                              epochs = setup.nn_epochs,
                              validation_data=([X_val[features_numeric]] + [X_val[f] for f in features_naics], 
                                               y_val),
                              shuffle=True,
                             callbacks=[callback])
    this_history_df = sbnn_model.process_history(this_history)
    this_history_df['rate'] = rate
    
    # Predictions then metrics
    this_predict = this_model.predict([X[features_numeric]]+ [X[f] for f in features_naics])
    this_predict_df = pd.DataFrame(this_predict, index=X.index) \
        .set_axis(['predict_prob'], axis=1) \
        .reset_index() \
        .merge(sba_loans[['target', 'LoanNr_ChkDgt', 'dset', 'dset_naics_holdout', 'NAICS']], 
               on='LoanNr_ChkDgt')
    
    # Threshold tune
    this_pred_train = this_predict_df[this_predict_df['dset'] == 'train']
    thresh_tune_data = sbnn_metrics.get_f1_frame(this_pred_train['target'], 
                                        this_pred_train['predict_prob'])
    thresh_tune_data.sort_values('f1', ascending=False, inplace=True)
    best_thresh = thresh_tune_data['thresh'].iloc[0]
    this_predict_df['predict_bin'] = sbnn_metrics.get_binary_predictions(this_predict_df['predict_prob'], 
                                                                            best_thresh)
    
    this_metrics_dset = this_predict_df.groupby('dset') \
        .apply(lambda x: sbnn_metrics.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
        .reset_index()
    this_metrics_test = this_predict_df[this_predict_df['dset'] == 'test'] \
        .groupby(['dset', 'dset_naics_holdout']) \
        .apply(lambda x: sbnn_metrics.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
        .reset_index()
    this_metrics = pd.concat([this_metrics_dset, this_metrics_test])
    this_metrics['rate'] = rate
    this_metrics['thresh'] = best_thresh
    this_metrics['train_size'] = len(X_train_ds)
    
    return this_history_df, this_metrics

# %% [markdown]
# ## Run Loop

# %%
sample_rate_vals = [0.01, 0.05, 0.1, 0.2, 0.4, 0.7, 0.9, 0.95, 0.99]

# %%
history = pd.DataFrame()
metrics = pd.DataFrame()

# %%
# %%capture
for r in sample_rate_vals:
    this_hist, this_met = gen_fit_loop(r)
    history = pd.concat([history, this_hist])
    metrics = pd.concat([metrics, this_met])
# Out:
# 2024-05-25 07:27:09.795150: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-05-25 07:27:09.795180: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-05-25 07:27:09.795187: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-05-25 07:27:09.795230: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-05-25 07:27:09.795251: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-05-25 07:27:10.679486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:27:14.929113: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:30:22.051440: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:31:19.060028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:31:27.555123: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:33:34.944460: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:34:23.570333: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:34:39.501177: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:40:25.546221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:41:16.548848: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:41:51.457149: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:48:24.732170: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:49:22.920931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 07:50:30.954954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 08:01:49.971323: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 08:02:40.663861: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 08:04:42.260570: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 08:33:30.778395: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 08:34:25.088672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 08:37:07.960031: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 09:01:37.448327: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 09:02:31.221516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 09:05:18.744342: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 09:39:54.914074: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 09:40:43.898857: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 09:43:04.621117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-05-25 10:07:26.425923: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
history['epoch'] = history.groupby('rate').cumcount()
history.to_csv(Path(setup.temp_path).joinpath('34_REPORT_loop_history.csv'))

# %%
metrics.to_csv(Path(setup.temp_path).joinpath('34_REPORT_loop_metrics.csv'))

# %%
metrics[metrics['dset_naics_holdout'] == 0]
# Out:
#    dset  accuracy_score  f1_score  precision_score  recall_score  \
# 0  test        0.573103  0.405601         0.282806      0.716868
# 0  test        0.591605  0.423279         0.296796      0.737626
# 0  test        0.616124  0.434722         0.310157      0.726500
# 0  test        0.645751  0.439228         0.323736      0.682823
# 0  test        0.649853  0.444765         0.328086      0.690240
# 0  test        0.654688  0.445382         0.330564      0.682411
# 0  test        0.648231  0.447084         0.328427      0.699974
# 0  test        0.661019  0.447273         0.334431      0.675045
# 0  test        0.657294  0.447776         0.332865      0.683853
#
#    average_precision_score  roc_auc_score  dset_naics_holdout  rate  thresh  \
# 0                 0.315488       0.672187                 0.0  0.01    0.18
# 0                 0.333983       0.693737                 0.0  0.05    0.18
# 0                 0.346791       0.705166                 0.0  0.10    0.20
# 0                 0.364643       0.714591                 0.0  0.20    0.26
# 0                 0.373609       0.721353                 0.0  0.40    0.22
# 0                 0.377877       0.724462                 0.0  0.70    0.22
# 0                 0.379639       0.726398                 0.0  0.90    0.26
# 0                 0.380609       0.726943                 0.0  0.95    0.26
# 0                 0.380559       0.726971                 0.0  0.99    0.22
#
#    train_size
# 0        4468
# 0       22342
# 0       44684
# 0       89369
# 0      178739
# 0      312793
# 0      402163
# 0      424505
# 0      442379

# %%
metrics[metrics['dset_naics_holdout'] == 1]
# Out:
#    dset  accuracy_score  f1_score  precision_score  recall_score  \
# 1  test        0.519629  0.414037         0.273505      0.851619
# 1  test        0.628951  0.423740         0.306835      0.684560
# 1  test        0.587205  0.429574         0.296414      0.779960
# 1  test        0.620915  0.434539         0.309175      0.730907
# 1  test        0.651041  0.436524         0.321821      0.678275
# 1  test        0.640622  0.436554         0.317468      0.698612
# 1  test        0.637300  0.437557         0.316626      0.707951
# 1  test        0.653476  0.437581         0.323388      0.676442
# 1  test        0.638117  0.437931         0.317122      0.707428
#
#    average_precision_score  roc_auc_score  dset_naics_holdout  rate  thresh  \
# 1                 0.315432       0.698339                 1.0  0.01    0.18
# 1                 0.315174       0.694951                 1.0  0.05    0.18
# 1                 0.340633       0.710439                 1.0  0.10    0.20
# 1                 0.344555       0.715300                 1.0  0.20    0.26
# 1                 0.346520       0.716550                 1.0  0.40    0.22
# 1                 0.350059       0.717207                 1.0  0.70    0.22
# 1                 0.351014       0.719131                 1.0  0.90    0.26
# 1                 0.353664       0.720219                 1.0  0.95    0.26
# 1                 0.351993       0.720161                 1.0  0.99    0.22
#
#    train_size
# 1        4468
# 1       22342
# 1       44684
# 1       89369
# 1      178739
# 1      312793
# 1      402163
# 1      424505
# 1      442379

# %% [markdown]
# ## Plots

# %%
#metrics = pd.read_csv(Path(setup.temp_path).joinpath('34_REPORT_loop_metrics.csv'))
#history = pd.read_csv(Path(setup.temp_path).joinpath('34_REPORT_loop_history.csv'))

# %%
importlib.reload(sbnn_plot)
# Out:
# <module 'sba_nn.sba_nn.sbnn_plot' from '/Users/valeriecarey/Documents/projects/2024_05_blog_nn_rand/code/sba_nn/sba_nn/sbnn_plot.py'>

# %% [markdown]
# ##### Metrics

# %%
fig = sbnn_plot.plot_metric_dependence(metrics, xformatter = ticker.PercentFormatter(1),
                                      ylabel='PR-AUC',
                            xlabel='downsample rate')
fig.savefig(Path(setup.temp_path).joinpath('34_PLOT_average_precision.png'),
            bbox_inches='tight')

# %% [markdown]
# ##### History

# %%
importlib.reload(sbnn_plot)
# Out:
# <module 'sba_nn.sba_nn.sbnn_plot' from '/Users/valeriecarey/Documents/projects/2024_05_blog_nn_rand/code/sba_nn/sba_nn/sbnn_plot.py'>

# %%
fig = sbnn_plot.plot_history_group(history,
                                  col_format_func = lambda x:f'{float(x):.1%}',
                                  ylabel = 'PR-AUC (validation)',
                                  leg_title='down rate')
fig.savefig(Path(setup.temp_path).joinpath('34_PLOT_hostory_val_auc.png'),
            bbox_inches='tight')

# %%
fig = sbnn_plot.plot_history_group(history,'val_loss',
                                  col_format_func = lambda x:f'{float(x):.1%}',
                                  ylabel = 'Loss (validation)',
                                  leg_title='down rate')
fig.savefig(Path(setup.temp_path).joinpath('34_PLOT_hostory_val_loss.png'),
            bbox_inches='tight')

# %%
fig = sbnn_plot.plot_epoch_agg(history,
                               xformatter = ticker.PercentFormatter(1),
                               ylabel='# Epochs',
                               xlabel='downsample rate')
fig.savefig(Path(setup.temp_path).joinpath('34_PLOT_hostory_epochs.png'),
            bbox_inches='tight')
